# %% [markdown]
# # 🕸️ Anti-Money Laundering (AML) — Graph Analysis & GNN
#
# **Dataset**: IBM Transactions for AML (237 votes) — realistic synthetic dataset
#
# ## Approach
# 1. Model transactions as a **graph**: nodes = accounts, edges = transactions
# 2. Graph features: PageRank, betweenness centrality, clustering coefficient
# 3. **Graph Neural Network (GNN)**: GraphSAGE / GCN for node classification
# 4. AML pattern detection: fan-out, fan-in, scatter-gather, U-turn

# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import warnings; warnings.filterwarnings('ignore')
print('Ready ✓')

# %%
df = pd.read_csv('/kaggle/input/ibm-transactions-for-anti-money-laundering-aml/HI-Small_Trans.csv')
print(df.shape)
print('Laundering rate:', df['Is Laundering'].mean())
df.head()

# %% [markdown]
# ## 2. Transaction Graph Construction

# %%
# Build directed graph
# G = nx.DiGraph()
# for _, row in df.iterrows():
#     G.add_edge(row['From Bank'], row['To Bank'],
#                amount=row['Amount Received'], label=row['Is Laundering'])

# Node-level features
# pagerank = nx.pagerank(G)
# betweenness = nx.betweenness_centrality(G)
# in_degree = dict(G.in_degree())
# out_degree = dict(G.out_degree())

# AML patterns:
# - Fan-out: 1 account → N accounts (layering/dispersion)
# - Fan-in: N accounts → 1 account (consolidation)
# - Cycle: loops in the graph
print('Graph construction — TODO')

# %% [markdown]
# ## 3. GNN — GraphSAGE for Node Classification
#
# Each account is a node. The GNN aggregates neighbor information to predict whether the account is involved in money laundering.

# %%
# pip install torch-geometric in a Kaggle notebook
# from torch_geometric.nn import SAGEConv
# from torch_geometric.data import Data

# class AMLGraphSAGE(torch.nn.Module):
#     def __init__(self, in_channels, hidden=64):
#         super().__init__()
#         self.conv1 = SAGEConv(in_channels, hidden)
#         self.conv2 = SAGEConv(hidden, 2)
#     def forward(self, x, edge_index):
#         x = F.relu(self.conv1(x, edge_index))
#         return self.conv2(x, edge_index)
print('GNN architecture — TODO')
